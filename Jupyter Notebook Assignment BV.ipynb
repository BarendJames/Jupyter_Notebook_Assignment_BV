# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# *I am interested in data science because I would like to find solutions to the world's polution problem through data analysis & model building*

# %% [markdown]
# ***The following code adds 2 variable numbers entered on Python***

# %%
x = input('Enter first number: ')
y = input('Enter second number: ')

sum = float(x) + float(y)

print('The total of {0} and {1} is {2}'.format(x, y, sum))
# Out:
# Enter first number: 8
# Enter second number: 9
# The total of 8 and 9 is 17.0

# %% [markdown]
# ***Block Quotes***
# > Follow the link below to a Markdown Cheat Sheet for more advanced Markdown Styling
#
# ***Horizontal Rule***
# ___
# ***
# ---
# ***
# ___
#
# ***
#
# ***Links***
# https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet
